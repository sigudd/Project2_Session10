# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_data=pd.read_csv("E:\DataScience\LearningMaterial\Project2\data-text.csv")
df_data.head() #Display first 5 rows of csv file
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
df1=pd.read_csv("berlin_weather_oldest.csv")
df1.head() #Display first 5 rows of csv file
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 2    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 3    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 4   -22 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
# 2 -9999 -9999
# ...

# %% [markdown]
# # 1. Get the Metadata from the above files.

# %%
df.info()
# Provides the info of dataframe df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 327.4+ KB

# %%
df1.info()
# Provides the info of dataframe df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %% [markdown]
# # 2. Get the row names from the above files.

# %%
df.index.values # provides index values of dataframe df
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
df1.index.values # provides index values of dataframe df
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %% [markdown]
# # 3. Change the column name from any of the above file.

# %%
df.rename(columns={'Indicator': 'IndicatorId'}) # Column name changed from indicator to indicator id
df.head()
# Out:
#                          IndicatorId Publication states  Year  \
# 0   Life expectancy at birth (years)          Published  1990
# 1   Life expectancy at birth (years)          Published  2000
# 2  Life expectancy at age 60 (years)          Published  2012
# 3  Life expectancy at age 60 (years)          Published  2000
# 4   Life expectancy at birth (years)          Published  2012
#
#               WHO Region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# ...

# %% [markdown]
# # 4. Change the column name from any of the above file and store the changes made
# permanently.

# %%
df.rename(columns={'Indicator': 'IndicatorId'}, inplace=True) # column name changed from indicator to indicator id permanently
df.head()
# Out:
#                          IndicatorId PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %% [markdown]
# # 5. Change the names of multiple columns.

# %%
df.rename(columns={'PUBLISH STATES': 'Publication Status','WHO region':'WHO Region'}, inplace=True) # multiple column names changed
df.head()
# Out:
#                                           IndicatorId Publication Status  \
# 4456  Healthy life expectancy (HALE) at birth (years)          Published
# 2798  Healthy life expectancy (HALE) at birth (years)          Published
# 3363  Healthy life expectancy (HALE) at birth (years)          Published
# 4457  Healthy life expectancy (HALE) at birth (years)          Published
# 2245  Healthy life expectancy (HALE) at birth (years)          Published
#
#       Year             WHO Region World Bank income group      Country  \
# 4456  2000  Eastern Mediterranean              Low-income  Afghanistan
# 2798  2000  Eastern Mediterranean              Low-income  Afghanistan
# 3363  2000  Eastern Mediterranean              Low-income  Afghanistan
# 4457  2012  Eastern Mediterranean              Low-income  Afghanistan
# 2245  2012  Eastern Mediterranean              Low-income  Afghanistan
#
#              Sex  Display Value  Numeric  Low  High  Comments
# ...

# %% [markdown]
# # 6. Arrange values of a particular column in ascending order.

# %%
df=df.sort_values('Year',ascending=True) # Year column is sorted in ascending order
df.head()
# Out:
#                             IndicatorId Publication states  Year  \
# 0      Life expectancy at birth (years)          Published  1990
# 1463  Life expectancy at age 60 (years)          Published  1990
# 1480  Life expectancy at age 60 (years)          Published  1990
# 1912  Life expectancy at age 60 (years)          Published  1990
# 1498   Life expectancy at birth (years)          Published  1990
#
#                  WHO Region World Bank income group     Country         Sex  \
# 0                    Europe             High-income     Andorra  Both sexes
# 1463        Western Pacific              Low-income        Niue      Female
# 1480  Eastern Mediterranean              Low-income     Somalia        Male
# 1912                 Africa              Low-income      Uganda        Male
# 1498                 Europe              Low-income  Tajikistan      Female
#
#       Display Value  Numeric  Low  High  Comments
# 0                77     77.0  NaN   NaN       NaN
# ...

# %% [markdown]
# # 7. Arrange multiple column values in ascending order.

# %%
df[['IndicatorId','Country','Year','WHO Region','Publication states']].head() # multiple column names sorted in ascending order
# Out:
#                                           IndicatorId      Country  Year  \
# 4456  Healthy life expectancy (HALE) at birth (years)  Afghanistan  2000
# 2798  Healthy life expectancy (HALE) at birth (years)  Afghanistan  2000
# 3363  Healthy life expectancy (HALE) at birth (years)  Afghanistan  2000
# 4457  Healthy life expectancy (HALE) at birth (years)  Afghanistan  2012
# 2245  Healthy life expectancy (HALE) at birth (years)  Afghanistan  2012
#
#                  WHO Region Publication states
# 4456  Eastern Mediterranean          Published
# 2798  Eastern Mediterranean          Published
# 3363  Eastern Mediterranean          Published
# 4457  Eastern Mediterranean          Published
# 2245  Eastern Mediterranean          Published

# %% [markdown]
# # 8. Make countryas the first column of the dataframe.

# %%
df[pd.unique(['Country']+df.columns.values.tolist()).tolist()].head()# country is made as the first column in the data frame followed by rest of the columns
# Out:
#           Country                                      IndicatorId  \
# 4456  Afghanistan  Healthy life expectancy (HALE) at birth (years)
# 2798  Afghanistan  Healthy life expectancy (HALE) at birth (years)
# 3363  Afghanistan  Healthy life expectancy (HALE) at birth (years)
# 4457  Afghanistan  Healthy life expectancy (HALE) at birth (years)
# 2245  Afghanistan  Healthy life expectancy (HALE) at birth (years)
#
#      Publication states  Year             WHO Region World Bank income group  \
# 4456          Published  2000  Eastern Mediterranean              Low-income
# 2798          Published  2000  Eastern Mediterranean              Low-income
# 3363          Published  2000  Eastern Mediterranean              Low-income
# 4457          Published  2012  Eastern Mediterranean              Low-income
# 2245          Published  2012  Eastern Mediterranean              Low-income
#
#              Sex  Display Value  Numeric  Low  High  Comments
# ...

# %% [markdown]
# # 9. Get the column array using a variable

# %%
df.Country.values # column array
# Out:
# array(['Afghanistan', 'Afghanistan', 'Afghanistan', ..., 'Zimbabwe',
#        'Zimbabwe', 'Zimbabwe'], dtype=object)

# %% [markdown]
# # 10. Get the subset rows 11, 24, 37

# %%
df.loc[[11,24,37]].head() # location of 11,24,37 is extracted and printed
# Out:
#                           IndicatorId Publication Status  Year  \
# 11   Life expectancy at birth (years)          Published  2012
# 24  Life expectancy at age 60 (years)          Published  2012
# 37  Life expectancy at age 60 (years)          Published  2012
#
#          WHO Region World Bank income group            Country     Sex  \
# 11           Europe             High-income            Austria  Female
# 24  Western Pacific             High-income  Brunei Darussalam  Female
# 37           Europe             High-income             Cyprus  Female
#
#     Display Value  Numeric  Low  High  Comments
# 11             83     83.0  NaN   NaN       NaN
# 24             21     21.0  NaN   NaN       NaN
# 37             26     26.0  NaN   NaN       NaN

# %% [markdown]
# # 11. Get the subset rows excluding 5, 12, 23, and 56

# %%
 
df.drop([4,11,22,55], axis=0).head() # index locations of specified has been dropped as it should be excluded
# Out:
#                                           IndicatorId Publication states  \
# 4456  Healthy life expectancy (HALE) at birth (years)          Published
# 2798  Healthy life expectancy (HALE) at birth (years)          Published
# 3363  Healthy life expectancy (HALE) at birth (years)          Published
# 4457  Healthy life expectancy (HALE) at birth (years)          Published
# 2245  Healthy life expectancy (HALE) at birth (years)          Published
#
#       Year             WHO Region World Bank income group      Country  \
# 4456  2000  Eastern Mediterranean              Low-income  Afghanistan
# 2798  2000  Eastern Mediterranean              Low-income  Afghanistan
# 3363  2000  Eastern Mediterranean              Low-income  Afghanistan
# 4457  2012  Eastern Mediterranean              Low-income  Afghanistan
# 2245  2012  Eastern Mediterranean              Low-income  Afghanistan
#
#              Sex  Display Value  Numeric  Low  High  Comments
# ...

# %% [markdown]
# # Load datasets from CSV

# %%
users=pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
sessions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')
products =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')
transactions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
users.head() # display first five rows of csv Users file
# Out:
#    UserID      User  Gender Registered  Cancelled
# 0       1   Charles    male 2012-12-21        NaT
# 1       2     Pedro    male 2010-08-01 2010-08-08
# 2       3  Caroline  female 2012-10-23 2016-06-07
# 3       4   Brielle  female 2013-07-17        NaT
# 4       5  Benjamin    male 2010-11-25        NaT

# %%
sessions.head()# display first five rows of csv Sessions file
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4

# %%
transactions.head()# display first five rows of csv transactions file
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1

# %% [markdown]
# # 12. Join users to transactions, keeping all rows from transactions and only matching rows from users (left join)

# %%
#result = pd.merge(transactions,
                 #users[['UserID', 'User', 'Gender','Registered','Cancelled']],
                # on='UserID')
#result.head()

result=pd.merge(transactions,users,how='left',on='UserID') # left join is made on transactions , merged transactions and users file
result.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
#
#    Gender Registered  Cancelled
# 0     NaN        NaT        NaT
# 1  female 2012-10-23 2016-06-07
# 2  female 2012-10-23 2016-06-07
# 3    male 2012-12-21        NaT
# 4    male 2010-08-01 2010-08-08

# %% [markdown]
# # 13. Which transactions have a UserID not in users?

# %%
transactions.loc[~transactions['UserID'].isin(users.UserID.values)] # ~ is used to display the list of rows of transactions table where user id is not present in users table
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3

# %% [markdown]
# # 14. Join users to transactions, keeping only rows from transactions and users that
# match via UserID (inner join)

# %%
result=pd.merge(transactions,users,how='inner',on='UserID') # making an inner join on transactions and users on User Id column
result.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
#
#    Gender Registered  Cancelled
# 0  female 2012-10-23 2016-06-07
# 1  female 2012-10-23 2016-06-07
# 2  female 2012-10-23 2016-06-07
# 3  female 2012-10-23 2016-06-07
# 4    male 2012-12-21        NaT

# %% [markdown]
# # 15. Join users to transactions, displaying all matching rows AND all non-matching rows(full outer join)

# %%
result=pd.merge(transactions,users,how='outer',on='UserID') # making an outer join on transactions and usrers table based on user id column
result.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0            1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1            9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2            2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3            3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4            7.0      2013-12-30     3.0        4.0       1.0  Caroline
#
#    Gender Registered  Cancelled
# 0     NaN        NaT        NaT
# 1     NaN        NaT        NaT
# 2  female 2012-10-23 2016-06-07
# 3  female 2012-10-23 2016-06-07
# 4  female 2012-10-23 2016-06-07

# %%
users['Registered'] = pd.to_datetime(users.Registered)
users['Cancelled'] = pd.to_datetime(users.Cancelled)
transactions['TransactionDate'] = pd.to_datetime(transactions.TransactionDate)
sessions['SessionDate']=pd.to_datetime(sessions.SessionDate)

# %% [markdown]
# # 16. Determine which sessions occurred on the same day each user registered

# %%
pd.merge(left=users,right=sessions,how='inner',left_on=['Registered'],right_on=['SessionDate'])#making an inner join on Users and session tyable to get the session date
# Out:
#    UserID_x      User  Gender Registered  Cancelled  SessionID SessionDate  \
# 0         1   Charles    male 2012-12-21        NaT          7  2012-12-21
# 1         2     Pedro    male 2010-08-01 2010-08-08          2  2010-08-01
# 2         3  Caroline  female 2012-10-23 2016-06-07          6  2012-10-23
# 3         4   Brielle  female 2013-07-17        NaT          9  2013-07-17
# 4         5  Benjamin    male 2010-11-25        NaT          3  2010-11-25
#
#    UserID_y
# 0         3
# 1         2
# 2         4
# 3         4
# 4         2

# %% [markdown]
# # 17. Build a dataset with every possible (UserID, ProductID) pair (cross join)

# %%
df1 = pd.DataFrame({'key': np.repeat(1, users.shape[0]), 'UserID': users.UserID})#shape of 0 give no of rows
df2 = pd.DataFrame({'key': np.repeat(1, products.shape[0]), 'ProductID': products.ProductID})
pd.merge(df1, df2,on='key')[['UserID', 'ProductID']]
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %% [markdown]
# # 18. Determine how much quantity of each product was purchased by each user

# %%
df1 = pd.DataFrame({'key': np.repeat(1, users.shape[0]), 'UserID': users.UserID}) # np repeat is used when both the tables doesnt have any sngle matching column
df2 = pd.DataFrame({'key': np.repeat(1, products.shape[0]), 'ProductID': products.ProductID})
user_products = pd.merge(df1, df2,on='key')[['UserID', 'ProductID']]
user_products.merge(transactions,how='outer')[['UserID', 'ProductID','Quantity']].fillna(0)
# Out:
#     UserID  ProductID  Quantity
# 0      1.0          1       0.0
# 1      1.0          2       3.0
# 2      1.0          3       0.0
# 3      1.0          4       0.0
# 4      1.0          5       0.0
# 5      2.0          1       0.0
# 6      2.0          2       0.0
# 7      2.0          3       0.0
# 8      2.0          4       1.0
# 9      2.0          5       6.0
# 10     3.0          1       0.0
# 11     3.0          2       0.0
# 12     3.0          3       1.0
# 13     3.0          4       1.0
# 14     3.0          4       1.0
# 15     3.0          4       4.0
# 16     3.0          5       0.0
# 17     4.0          1       0.0
# 18     4.0          2       0.0
# 19     4.0          3       0.0
# 20     4.0          4       0.0
# 21     4.0          5       0.0
# 22     5.0          1       0.0
# 23     5.0          2       0.0
# 24     5.0          3       0.0
# 25     5.0          4       0.0
# 26     5.0          5       0.0
# 27     7.0          2       1.0
# ...

# %% [markdown]
# # 19. For each user, get each possible pair of pair transactions (TransactionID1, TransacationID2)

# %%
pd.merge(transactions, transactions, on='UserID') # merging two same tables
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                 1        2010-08-21     7.0            2           1
# 1                 1        2010-08-21     7.0            2           1
# 2                 9        2015-04-24     7.0            4           3
# 3                 9        2015-04-24     7.0            4           3
# 4                 2        2011-05-26     3.0            4           1
# 5                 2        2011-05-26     3.0            4           1
# 6                 2        2011-05-26     3.0            4           1
# 7                 2        2011-05-26     3.0            4           1
# 8                 3        2011-06-16     3.0            3           1
# 9                 3        2011-06-16     3.0            3           1
# 10                3        2011-06-16     3.0            3           1
# 11                3        2011-06-16     3.0            3           1
# ...

# %% [markdown]
# # 20. Join each user to his/her first occuring transaction in the transactions table

# %%
x=pd.merge(users,transactions,on='UserID',how='left') 
x.groupby('UserID').first() # first is used to get the first rows
# Out:
#             User  Gender Registered  Cancelled  TransactionID TransactionDate  \
# UserID
# 1        Charles    male 2012-12-21        NaT            4.0      2012-08-26
# 2          Pedro    male 2010-08-01 2010-08-08            5.0      2013-06-06
# 3       Caroline  female 2012-10-23 2016-06-07            2.0      2011-05-26
# 4        Brielle  female 2013-07-17        NaT            NaN             NaT
# 5       Benjamin    male 2010-11-25        NaT            NaN             NaT
#
#         ProductID  Quantity
# UserID
# 1             2.0       3.0
# 2             4.0       1.0
# 3             4.0       1.0
# 4             NaN       NaN
# 5             NaN       NaN

# %% [markdown]
# # 21. Test to see if we can drop columns

# %%
products.drop(['Product'], axis=1) # dropping a column product in products
# Out:
#    ProductID  Price
# 0          1  14.16
# 1          2  33.04
# 2          3  10.65
# 3          4  10.02
# 4          5  29.66
